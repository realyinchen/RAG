# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="qwen-max-latest", temperature=0)

# %%
from helper_functions import (
    get_local_embedding_model,
    get_vector_store,
    text_wrap,
    show_context,
)

embedding_model = get_local_embedding_model()
vector_store = get_vector_store(
    embedding_model,
    collection_name="Understanding_Climate_Change",
)

# %%
from langchain_core.prompts import PromptTemplate

hyde_prompt = PromptTemplate(
    input_variables=["query", "chunk_size"],
    template="""Given the question '{query}', generate a hypothetical document that directly answers this question. 
    The document should be detailed and in-depth. the document size has be exactly {chunk_size} characters.""",
)

hyde_chain = hyde_prompt | llm

# %%
query = "What is the main cause of climate change?"

hypothetical_doc = hyde_chain.invoke({"query": query, "chunk_size": 4000}).content
similar_docs = vector_store.similarity_search(hypothetical_doc, k=3)

docs_content = [doc.page_content for doc in similar_docs]

print("假设文档:\n")
print(text_wrap(hypothetical_doc) + "\n")
show_context(docs_content)
# Out:
# 假设文档:
#
# # Understanding Climate Change: An Overview  Climate change, a term that has permeated global discourse in recent
# decades, refers to the long-term alteration of Earth's average weather patterns and temperatures. This phenomenon
# encompasses not only rising global temperatures but also significant shifts in precipitation patterns, sea levels, and
# the frequency of extreme weather events. At its core, climate change is driven by changes in the Earth's energy balance,
# where more heat is retained within the atmosphere than is radiated back into space. The implications of this imbalance
# are profound, affecting ecosystems, economies, and human societies on a planetary scale.  The importance of
# understanding the primary causes of climate change cannot be overstated. Scientific consensus indicates that human
# activities are now the dominant force driving these climatic transformations. While natural factors such as volcanic
# eruptions and variations in solar radiation have historically influenced Earth's climate, their impact pales in
# comparison to the rapid changes observed since the Industrial Revolution. The unprecedented rate of current climate
# change poses unique challenges, as natural systems struggle to adapt to such accelerated environmental modifications.
# Addressing climate change requires a comprehensive understanding of its root causes. Without identifying and
# acknowledging these fundamental drivers, effective mitigation strategies become impossible to implement. Moreover,
# recognizing the primary sources of climate-altering emissions enables policymakers, scientists, and citizens to target
# interventions where they can have the most significant impact. This document aims to provide a thorough examination of
# the main cause of climate change, exploring both historical context and contemporary scientific understanding while
# maintaining focus on the central role of human activity in shaping our planet's changing climate.  ## The Dominant Human
# Factor in Climate Change  The overwhelming scientific consensus identifies human activities as the principal driver of
# contemporary climate change. According to the Intergovernmental Panel on Climate Change (IPCC), human influence has been
# the dominant cause of observed warming since the mid-20th century, with confidence levels exceeding 95%. This conclusion
# stems from decades of meticulous research and analysis across multiple scientific disciplines, including atmospheric
# science, oceanography, and paleoclimatology. The evidence manifests through various interconnected indicators, each
# pointing unmistakably to anthropogenic influences as the primary catalyst for current climatic transformations.  Several
# key mechanisms demonstrate humanity's role in altering Earth's climate system. First, the unprecedented increase in
# greenhouse gas concentrations, particularly carbon dioxide (CO2), methane (CH4), and nitrous oxide (N2O), directly
# correlates with industrial and agricultural activities. These gases trap heat in Earth's atmosphere through the enhanced
# greenhouse effect, creating an energy imbalance that drives global warming. Second, land-use changes, primarily
# deforestation and urbanization, have significantly altered natural carbon sinks and surface reflectivity (albedo),
# further amplifying warming trends. Third, aerosol emissions from industrial processes and fossil fuel combustion affect
# cloud formation and atmospheric chemistry, creating complex feedback loops that influence climate patterns.  The scale
# and speed of these human-induced changes exceed any natural climate variability observed throughout geological history.
# For instance, atmospheric CO2 concentrations have increased by over 50% since pre-industrial times, reaching levels not
# seen in at least three million years. This rapid accumulation far outpaces natural carbon cycle processes, leaving
# Earth's systems insufficient time to adapt. Similarly, the current rate of temperature increase – approximately 0.2°C
# per decade – represents an order of magnitude faster than natural climate transitions documented in paleoclimate
# records.  Scientific organizations worldwide, including NASA, NOAA, and the World Meteorological Organization,
# consistently affirm the human fingerprint on climate change through rigorous empirical evidence. This includes precise
# measurements of isotopic signatures in atmospheric CO2, which definitively link rising concentrations to fossil fuel
# combustion, and sophisticated climate models that accurately reproduce observed temperature trends only when
# anthropogenic factors are included. The convergence of evidence from multiple independent lines of inquiry leaves little
# room for doubt regarding humanity's central role in driving contemporary climate change.  ## Fossil Fuel Combustion: The
# Primary Driver of Climate Change  Among all human activities contributing to climate change, the burning of fossil fuels
# stands as the single most significant factor, accounting for approximately 75% of global greenhouse gas emissions. This
# dominance stems from the pervasive role fossil fuels play in modern society, powering everything from transportation
# networks to industrial facilities, electricity generation to residential heating. The combustion process releases vast
# quantities of carbon dioxide (CO2) and other greenhouse gases into the atmosphere, fundamentally altering Earth's
# natural carbon cycle and energy balance.  The relationship between fossil fuel use and climate change unfolds through
# several critical mechanisms. When coal, oil, or natural gas is burned, the chemical bonds holding carbon atoms together
# break apart, releasing energy along with CO2 molecules. These molecules accumulate in the atmosphere, where they act
# like a thickening blanket, trapping heat that would otherwise escape into space. The concentration of atmospheric CO2
# has risen from approximately 280 parts per million (ppm) before the Industrial Revolution to over 420 ppm today, with
# fossil fuel combustion responsible for roughly 85% of this increase.  The impact extends beyond mere quantity; the
# timing and spatial distribution of emissions amplify their effects. Unlike natural carbon sources, which operate on
# geological timescales, human activities release carbon rapidly – millions of years' worth of sequestered carbon in just
# centuries. This temporal mismatch creates an artificial spike in atmospheric CO2 levels, forcing climate systems to
# respond much faster than natural adaptation processes can accommodate. Furthermore, the global nature of fossil fuel
# consumption means emissions originate from every inhabited continent, creating a uniform warming effect that affects
# climate patterns worldwide.  Energy production represents the largest sectoral contributor, with coal-fired power plants
# alone responsible for about 40% of global CO2 emissions. Transportation follows closely behind, with internal combustion
# engines in vehicles emitting not only CO2 but also other potent greenhouse gases like nitrous oxides. Industrial
# processes add another significant dimension, as high-temperature manufacturing and chemical production require
# substantial fossil fuel inputs while simultaneously releasing process-related emissions. The cumulative effect creates a
# self-reinforcing cycle, where economic growth traditionally dependent on fossil fuels generates more emissions, which in
# turn drive climate impacts that threaten economic stability.  The persistence of fossil fuel infrastructure and policy
# frameworks exacerbates the problem. Existing investments in coal mines, oil fields, pipelines, and refineries create
# powerful economic incentives to maintain current consumption patterns. Meanwhile, subsidies for fossil fuel industries
# globally amount to hundreds of billions of dollars annually, distorting market signals and hindering the transition to
# cleaner alternatives. This entrenched dependency makes fossil fuel combustion not just a technical challenge but a
# complex socio-economic issue requiring coordinated global action.  ## The Carbon Cycle Disruption and Atmospheric Impact
# The natural carbon cycle represents one of Earth's most sophisticated regulatory systems, maintaining a delicate balance
# between carbon reservoirs and atmospheric concentrations over geological timescales. Under normal circumstances, carbon
# moves through various "sinks" and "sources" in predictable patterns: oceans absorb CO2 from the atmosphere, forests and
# other vegetation sequester carbon during photosynthesis, and soil microorganisms gradually incorporate organic matter
# into terrestrial reserves. Volcanic eruptions and natural forest fires release carbon back into the atmosphere,
# completing the cycle. However, human activities have fundamentally disrupted this equilibrium, causing atmospheric
# carbon levels to rise at unprecedented rates.  The disruption begins with the extraction and combustion of fossil fuels,
# which effectively transfers ancient carbon stores from deep underground reservoirs directly into the atmosphere. Coal
# deposits formed over hundreds of millions of years are now being consumed within centuries, while oil and natural gas
# reserves accumulated over tens of millions of years are being depleted within decades. This rapid transfer overwhelms
# natural carbon sinks, which cannot absorb the excess carbon quickly enough to maintain balance. Oceans, though capable
# of absorbing significant amounts of CO2, do so at a cost: increasing acidity threatens marine ecosystems and reduces
# their capacity for future absorption.  Simultaneously, human activities degrade existing carbon sinks through
# deforestation, agricultural expansion, and urban development. Tropical rainforests, once crucial carbon reservoirs, are
# being cleared at alarming rates, releasing stored carbon while eliminating future sequestration potential. Agricultural
# practices often reduce soil carbon content through intensive tilling and monoculture farming, further diminishing
# terrestrial storage capacity. Urbanization replaces vegetative cover with impermeable surfaces, reducing local carbon
# uptake while increasing energy demands.  This systematic disruption manifests in measurable atmospheric changes. The
# Keeling Curve, tracking atmospheric CO2 concentrations since 1958, shows an unbroken upward trend superimposed on
# natural seasonal variations. Isotopic analysis confirms that the additional carbon originates primarily from fossil fuel
# sources, evidenced by distinct carbon-13 and carbon-14 signatures. As atmospheric CO2 levels rise, the enhanced
# greenhouse effect intensifies, with more infrared radiation being trapped near Earth's surface. This creates a positive
# feedback loop: warming temperatures accelerate carbon release from natural sources like permafrost and ocean reservoirs,
# further amplifying atmospheric concentrations.  The consequences extend beyond simple warming. Increased CO2 affects
# plant physiology through enhanced photosynthesis rates, potentially altering ecosystem compositions and agricultural
# productivity patterns. Changes in atmospheric chemistry influence cloud formation and precipitation cycles, while ocean
# acidification impacts marine food webs and carbon sequestration dynamics. Each of these effects interacts with others in
# complex ways, creating cascading impacts throughout Earth's climate system.  ## Economic and Social Implications of
# Fossil Fuel Dependency  The global economy's entrenchment in fossil fuel infrastructure creates formidable barriers to
# addressing climate change. Investment in carbon-intensive assets has reached staggering proportions, with estimates
# suggesting over $25 trillion in stranded assets risk if countries meet their Paris Agreement commitments. Major
# industries, from automobile manufacturing to steel production, have optimized their operations around cheap fossil fuel
# availability, making transition costs prohibitive without substantial government intervention. The energy sector itself
# faces particular challenges, as utility companies must navigate the delicate balance between maintaining reliable
# service and investing in renewable technologies while managing existing fossil fuel infrastructure obligations.  Social
# dimensions compound these economic challenges. Fossil fuel industries provide direct employment to millions worldwide,
# particularly in regions where alternative economic opportunities remain limited. In the United States alone, the coal
# mining sector supports nearly 500,000 jobs directly and indirectly, while the broader fossil fuel industry employs over
# 10 million workers. Transitioning away from these traditional energy sources without adequate support systems risks
# severe social disruption, including widespread unemployment and community destabilization. The political influence of
# fossil fuel interests further complicates reform efforts, as these industries wield significant lobbying power and
# campaign contributions that shape energy policies favorable to continued fossil fuel dependence.  Infrastructure lock-in
# presents another critical obstacle. Cities designed around automobile transportation, industrial zones powered by coal
# plants, and agricultural systems dependent on synthetic fertilizers derived from natural gas create path dependencies
# that resist change. Retrofitting existing buildings for energy efficiency, replacing gasoline-powered vehicles with
# electric alternatives, and developing new industrial processes all require massive capital investment and coordination
# across multiple sectors. The sunk costs associated with current infrastructure make these transitions economically
# challenging, particularly for developing nations seeking to expand energy access while meeting climate goals.  The
# psychological aspect of change resistance also plays a significant role. Many communities identify strongly with their
# fossil fuel heritage, viewing attempts to transition away as attacks on their cultural identity and way of life. This
# emotional attachment manifests in political polarization around climate policies, making consensus-building difficult
# even when economic arguments favor renewable energy adoption. Additionally, the intermittent nature of many renewable
# energy sources requires technological advancements in energy storage and grid management, creating uncertainty about
# reliability and stability during the transition period.  ## Evidence Linking Fossil Fuels to Climate Change  The
# scientific evidence connecting fossil fuel combustion to climate change emerges from multiple converging lines of
# inquiry, each reinforcing the causal relationship through different analytical approaches. Ice core samples extracted
# from Antarctica and Greenland provide perhaps the most compelling historical record, revealing a clear correlation
# between past atmospheric CO2 levels and global temperatures over 800,000 years. The isotopic composition of carbon in
# these ancient air bubbles matches precisely with the signature of fossil fuel-derived CO2, demonstrating that current
# atmospheric concentrations represent an artificial spike above natural variability. Advanced dating techniques confirm
# that the rapid increase in CO2 began coincidentally with the onset of industrial-scale fossil fuel use in the late 18th
# century.  Modern observational data presents equally compelling evidence. Satellite measurements show a consistent
# increase in outgoing longwave radiation being trapped by greenhouse gases, with spectral analysis pinpointing
# CO2-specific absorption bands growing stronger over time. Ground-based monitoring stations worldwide report identical
# trends in atmospheric composition changes, with urban areas showing elevated levels corresponding to local fossil fuel
# consumption patterns. Oceanographic studies document increasing seawater acidity and declining oxygen levels, both
# directly attributable to excess atmospheric CO2 originating from fossil fuel combustion.  Computer modeling provides
# additional verification through predictive capabilities. Climate models incorporating fossil fuel emissions accurately
# reproduce observed temperature trends, sea level rise, and ice melt patterns across multiple timescales. When natural
# factors alone are considered, these models fail to explain current climate observations. Notably, the geographic
# distribution of warming aligns perfectly with expected patterns from greenhouse gas forcing, showing greater temperature
# increases over land than oceans and stronger warming at higher latitudes – exactly what physics predicts from fossil
# fuel-driven CO2 increases. The consistency between model predictions and real-world observations strengthens confidence
# in the causal relationship.  Direct measurement of fossil fuel emissions through satellite technology offers perhaps the
# most definitive proof. Instruments aboard spacecraft can now detect and quantify CO2 plumes from individual power plants
# and industrial facilities, matching these observations with reported emissions data. This capability allows scientists
# to track carbon flows in near real-time, confirming that human activities account for the observed atmospheric CO2
# increase. Similar techniques applied to methane emissions reveal hotspots directly linked to oil and gas operations,
# providing additional evidence of fossil fuel industry contributions to climate change.  ## Addressing Climate Change
# Through Targeted Solutions  Effectively combating climate change necessitates strategic interventions that prioritize
# reducing fossil fuel dependency while simultaneously enhancing natural carbon sequestration capabilities. The most
# promising solutions emerge from a multi-faceted approach combining technological innovation, policy reform, and
# behavioral change. Renewable energy deployment stands as the cornerstone of mitigation efforts, with solar and wind
# power costs plummeting by over 80% in the past decade. Aggressive investment in grid modernization and energy storage
# technologies can address intermittency concerns, enabling these clean sources to replace fossil fuel baseload
# generation. Particularly successful examples include Germany's Energiewende program, which has reduced coal dependence
# by 40% while maintaining grid stability through advanced integration techniques.  Targeted policy measures play a
# crucial role in accelerating the transition. Carbon pricing mechanisms, implemented through either cap-and-trade systems
# or direct taxes, create economic incentives for emission reductions while generating revenue for clean energy
# investments. British Columbia's carbon tax, introduced in 2008, demonstrates how carefully designed pricing schemes can
# achieve significant emission cuts without harming economic growth. Complementary regulations, such as vehicle emission
# standards and building efficiency codes, ensure steady progress across all sectors. The European Union's Emissions
# Trading System provides another effective model, having reduced covered sector emissions by 35% since 2005.  Natural
# climate solutions offer powerful complementary approaches to technological fixes. Large-scale reforestation and improved
# forest management could sequester up to 10 gigatons of CO2 annually, while regenerative agriculture practices enhance
# soil carbon storage while improving crop yields. Costa Rica's payment for ecosystem services program exemplifies
# successful forest conservation through economic incentives, achieving double-digit annual reforestation rates. Urban
# green infrastructure initiatives, such as New York City's MillionTreesNYC project, demonstrate how cities can integrate
# nature-based solutions into climate action plans.  Behavioral and cultural shifts represent equally vital components of
# effective climate response. Transportation sector reforms focusing on public transit expansion, cycling infrastructure,
# and remote work policies can significantly reduce personal vehicle usage. Copenhagen's transformation into a cycling-
# centric city reduced transport emissions by 60% while improving public health outcomes. Food system changes,
# particularly reduced meat consumption and food waste prevention, offer substantial emission reduction potential
# alongside nutritional benefits. The Netherlands' circular economy initiatives showcase how systematic waste reduction
# and resource efficiency improvements can drive sustainable economic growth.  ## A Collective Responsibility for Climate
# Action  The evidence presented underscores an undeniable reality: human activities, particularly fossil fuel combustion,
# stand as the predominant force driving contemporary climate change. This conclusion emerges not from isolated
# observations but from a robust synthesis of historical climate records, isotopic analyses, satellite measurements, and
# sophisticated climate modeling. The unprecedented rate of atmospheric CO2 increase, coupled with its distinctive fossil
# fuel signature, leaves no ambiguity regarding the primary source of current climatic disruptions. Natural factors, while
# influential in Earth's past climate variations, cannot account for the rapid and sustained warming observed since the
# Industrial Revolution.  Recognizing humanity's central role in climate change carries profound implications for our
# collective responsibility. The same ingenuity that enabled industrial advancement must now be redirected toward
# mitigating its unintended consequences. This requires acknowledging that climate change represents not merely an
# environmental issue but a fundamental challenge to our economic systems, social structures, and technological paradigms.
# The solutions lie within our grasp, from proven renewable energy technologies to nature-based carbon sequestration
# methods, but their implementation demands unprecedented cooperation and commitment across all sectors of society.  The
# path forward demands immediate and sustained action. Delayed responses will only exacerbate the challenges we face, as
# the inertia inherent in Earth's climate system means today's emissions commit us to future warming. Every ton of CO2
# avoided represents a tangible contribution to preserving ecological stability and human well-being. This understanding
# must translate into concrete actions, from individual lifestyle choices to corporate sustainability initiatives and
# government policy reforms. The window for meaningful intervention remains open, but its duration shortens with each
# passing year, emphasizing the urgency of embracing our shared responsibility to address climate change.
#
# Context 1:
# Most of these climate changes are attributed to very small variations in Earth's orbit that
# change the amount of solar energy our planet receives. During the Holocene epoch, which
# began at the end of the last ice age, human societies flourished, but the industrial era has seen
# unprecedented changes.
# Modern Observations
# Modern scientific observations indicate a rapid increase in global temperatures, sea levels,
# and extreme weather events. The Intergovernmental Panel on Climate Change (IPCC) has
# documented these changes extensively. Ice core samples, tree rings, and ocean sediments
# provide a historical record that scientists use to understand past climate conditions and
# predict future trends. The evidence overwhelmingly shows that recent changes are primarily
# driven by human activities, particularly the emission of greenhouse gases.
# Chapter 2: Causes of Climate Change
# Greenhouse Gases
# The primary cause of recent climate change is the increase in greenhouse gases in the
#
#
# Context 2:
# Chapter 2: Causes of Climate Change
# Greenhouse Gases
# The primary cause of recent climate change is the increase in greenhouse gases in the
# atmosphere. Greenhouse gases, such as carbon dioxide (CO2), methane (CH4), and nitrous
# oxide (N2O), trap heat from the sun, creating a "greenhouse effect." This effect is essential
# for life on Earth, as it keeps the planet warm enough to support life. However, human
# activities have intensified this natural process, leading to a warmer climate.
# Fossil Fuels
# Burning fossil fuels for energy releases large amounts of CO2. This includes coal, oil, and
# natural gas used for electricity, heating, and transportation. The industrial revolution marked
# the beginning of a significant increase in fossil fuel consumption, which continues to rise
# today.
# Coal
# Coal is the most carbon-intensive fossil fuel, and its use for electricity generation is a major
# source of CO2 emissions. Despite a decline in some regions, coal remains a significant
#
#
# Context 3:
# Understanding Climate Change
# Chapter 1: Introduction to Climate Change
# Climate change refers to significant, long-term changes in the global climate. The term
# "global climate" encompasses the planet's overall weather patterns, including temperature,
# precipitation, and wind patterns, over an extended period. Over the past century, human
# activities, particularly the burning of fossil fuels and deforestation, have significantly
# contributed to climate change.
# Historical Context
# The Earth's climate has changed throughout history. Over the past 650,000 years, there have
# been seven cycles of glacial advance and retreat, with the abrupt end of the last ice age about
# 11,700 years ago marking the beginning of the modern climate era and human civilization.
# Most of these climate changes are attributed to very small variations in Earth's orbit that
# change the amount of solar energy our planet receives. During the Holocene epoch, which
